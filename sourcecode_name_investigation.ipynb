# %% [markdown]
# # This Notebook explores the SCAR GeoMAP dataset released in 2019
# ## Cox S.C., Smith Lyttle B. and the GeoMAP team (2019). Lower Hutt, New Zealand. GNS Science. Release v.201907.
# ### [Data Available Here](https://data.gns.cri.nz/ata_geomap/index.html?content=/mapservice/Content/antarctica/www/index.html)

# %% [markdown]
# ### Notebook by Sam Elkind

# %%
import os
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import pprint as pp
from tabulate import tabulate

# %%
def plot_value_counts(field_name, values_to_plot, counts, counts_norm):
    fig, ax = plt.subplots(2, 1, figsize=(30,15))
    fig.tight_layout(pad=2.0)
    fig.subplots_adjust(top=.94)
    fig.suptitle(f"Frequency of {field_name} values", size=18)

    ax[0].set_title(field_name)
    ax[1].set_title(f"{field_name} normalized")
    for i, v in enumerate(counts[:values_to_plot]):
        ax[0].text(i - .5, v, str(v), color='black', fontweight='bold')
    for i, v in enumerate(counts_norm[:values_to_plot]):
        ax[1].text(i - .5, v, f"{str(v * 100)[:3]}%", color='black', fontweight='bold')
    ax[0].bar(counts.index[:values_to_plot], counts[:values_to_plot])
    ax[1].bar(counts_norm.index[:values_to_plot], counts_norm[:values_to_plot])

# %%
geol_path = f"{os.getcwd()}/data/ATA_SCAR_GeoMAP_geology.gdb"
print(geol_path)
# Out:
# /home/sam/geomap/data/ATA_SCAR_GeoMAP_geology.gdb

# %%
data = gpd.read_file(geol_path)

# %% [markdown]
# # Exploring the discrepancy between polygon names and source codes

# %%
display(data[["SOURCECODE","NAME"]].nunique())
# Out:
# SOURCECODE    801
# NAME          666
# dtype: int64

# %% [markdown]
# ## Why are there more source codes than names?
# ### Let's make a set of sourecodes for each unique name.

# %%
name_src_code_vals = sorted([data[data["NAME"] == i][["MAPSYMBOL", "SOURCECODE", "SOURCE", "NAME", "DESCR"]].drop_duplicates("SOURCECODE") for i in data["NAME"].drop_duplicates()], key=lambda x: len(x), reverse=True)
name_src_code_counts = pd.DataFrame([(i["NAME"], len(i)) for i in name_src_code_vals if len(i) > 1])

# %%
display(name_src_code_counts)
# Out:
#                                                     0   1
# 0   41773    Marie Byrd Land Volcanics: basalt
# 417...  17
# 1   41781    Marie Byrd Land Volcanics: trachyte
# 4...  11
# 2   60905    Melbourne volcanic province
# 61140    ...  11
# 3   60975    Hallett volcanic province
# 61016    Ha...  10
# 4   41775    Marie Byrd Land Volcanics: undifferen...   7
# 5   44248    late granitoid
# 55116    late granitoi...   5
# 6   40463    older ice sheet margin till
# 43686    ...   4
# 7   77020    Marble, calc-silicate and skarn
# 81058...   4
# 8   79090    Amphibolite
# 80168    Amphibolite
# 8149...   4
# 9   80654    Garnet-biotite gneiss
# 83956    Garnet...   4
# 10  35808    Granitoid intrusions
# 35923    Granito...   3
# 11  37965    supraglacial till
# 54453    supraglaci...   3
# 12  40022    unknown
# 40800    unknown
# 43645    unk...   3
# 13  40797    colluvium and scree
# 43852    colluviu...   3
# 14  41782    Marie Byrd Land Volcanics: mugearite
# ...   3
# 15  41836    Marie Byrd Land Volcanics: phonolite
# ...   3
# 16  45427    Kirkpatrick Basalt
# 60932    Kirkpatri...   3
# 17  82951    Biotite-hornblende gneiss
# 83434    Bi...   3
# 18  86192    Beaver Complex
# 86279    Beaver Comple...   3
# 19  20       outcrop of unknown rock type
# 37093   ...   2
# 20  41367    undifferentiated till
# 54493    undiff...   2
# 21  41522    Ruppert Coast metavolcanics
# 41861    ...   2
# 22  41777    Marie Byrd Land Volcanics: hawaiite
# 4...   2
# 23  41793    Kohler Range granitoids
# 41895    Kohl...   2
# 24  41832    Marie Byrd Land Volcanics: comendite
# ...   2
# 25  41837    Marie Byrd Land Volcanics: benmoreite...   2
# 26  43072    undifferentiated granitoid
# 43627    u...   2
# 27  43406    Ferrar Dolerite
# 60912    Ferrar Doler...   2
# 28  43447    undifferentiated Skelton Group
# 55861 ...   2
# 29  55120    schist
# 57799    schist
# Name: NAME, dt...   2
# 30  59170    Skelton Mafic Intrusives
# 59245    Ske...   2
# 31  59643    Beacon Heights Orthoquartzite
# 59694  ...   2
# 32  61267    Section Peak Formation
# 61770    Secti...   2
# 33  78057    Pelitic gneiss and schist
# 79244    Pe...   2
# 34  80593    Hornblende gneiss
# 81569    Hornblende...   2
# 35  81505    Pyroxene syenite
# 84369    Pyroxene sy...   2
# 36  82945    Banded gneiss
# 84906    Banded gneiss
# ...   2
# 37  83310    Granitic gneiss and migmatite
# 85128 ...   2
# 38  84069    Granodiorite-diorite
# 84866    Granodi...   2
# 39  84084    Sillimanite-garnet-biotite gneiss
# 845...   2
# 40  84372    Mafic granulite/mafic lenses
# 84647   ...   2
# 41  85931    Prydz Complex
# 86293    Prydz Complex
# ...   2
# 42  87672    Lambert series (in part)
# 87673    Lam...   2
# 43  88156    Grove Complex
# 90589    Grove Complex
# ...   2
# 44  94141    Shaw-Clemence Complex
# 94142    Shaw-C...   2

# %% [markdown]
# #### There are 44 unit names that have a variety of sourcecodes. These names are either compositionally descriptive or are part of a complex that is further differentiated by sourcecode. Perhaps some of the latter category could have their sources reviewed for more specific unit names for this field.
