# %% [markdown]
# # This Notebook explores the SCAR GeoMAP dataset released in 2019
# ## Cox S.C., Smith Lyttle B. and the GeoMAP team (2019). Lower Hutt, New Zealand. GNS Science. Release v.201907.
# ### [Data Available Here](https://data.gns.cri.nz/ata_geomap/index.html?content=/mapservice/Content/antarctica/www/index.html)

# %% [markdown]
# ### Notebook by Sam Elkind

# %% [markdown]
# ### Configure packages, paths, and load data

# %%
import os
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import pprint as pp
from tabulate import tabulate

# %%
def plot_value_counts(field_name, values_to_plot, counts, counts_norm):
    fig, ax = plt.subplots(2, 1, figsize=(30,15))
    fig.tight_layout(pad=2.0)
    fig.subplots_adjust(top=.94)
    fig.suptitle(f"Frequency of {field_name} values", size=18)

    ax[0].set_title(field_name)
    ax[1].set_title(f"{field_name} normalized")
    for i, v in enumerate(counts[:values_to_plot]):
        ax[0].text(i - .5, v, str(v), color='black', fontweight='bold')
    for i, v in enumerate(counts_norm[:values_to_plot]):
        ax[1].text(i - .5, v, f"{str(v * 100)[:3]}%", color='black', fontweight='bold')
    ax[0].bar(counts.index[:values_to_plot], counts[:values_to_plot])
    ax[1].bar(counts_norm.index[:values_to_plot], counts_norm[:values_to_plot])

# %%
geol_path = f"{os.getcwd()}/data/ATA_SCAR_GeoMAP_geology.gdb"
print(geol_path)
# Out:
# /home/sam/geomap/data/ATA_SCAR_GeoMAP_geology.gdb

# %%
data = gpd.read_file(geol_path)

# %% [markdown]
# # MAPSYMBOL, PLOTSYMBOL and the relationship between them

# %% [markdown]
# ## There are fewer than 200 values, so let's make bar charts of the top halves and bottom halves of each field

# %%
map_sym_counts = data["MAPSYMBOL"].value_counts(ascending=False)
map_sym_counts_norm = data["MAPSYMBOL"].value_counts(ascending=False, normalize=True)
display(pd.DataFrame(map_sym_counts))
# Out:
#       MAPSYMBOL
# JKg        6608
# EOg        4707
# ?          4654
# CTw        4479
# EOs        4015
# ...         ...
# ARzg          2
# Qk            2
# Rzh           1
# JKj           1
# Et            1
#
# [173 rows x 1 columns]

# %%
plot_value_counts("MAPSYMBOL", 85, map_sym_counts, map_sym_counts_norm)

# %%
plot_sym_counts = data["PLOTSYMBOL"].value_counts(ascending=False)
plot_sym_counts_norm = data["PLOTSYMBOL"].value_counts(ascending=False, normalize=True)

# %%
print(plot_sym_counts)
# Out:
# JKg     6608
# EOg     4707
# ?       4654
# CTw     4479
# EOs     4015
#         ...
# Pzq        2
# ARzg       2
# JKj        1
# Rzh        1
# Et         1
# Name: PLOTSYMBOL, Length: 183, dtype: int64

# %%
plot_value_counts("PLOTSYMBOL", 90, plot_sym_counts, plot_sym_counts_norm)

# %% [markdown]
# ## The distribution of these two fields look identical. However, plotsymbol has 10 more values. What explains this discrepancy?

# %% [markdown]
# ### Let's start by identifying the distinct values.

# %%
map_not_plot = sorted([i for i in map_sym_counts.index if i not in plot_sym_counts.index])
plot_not_map = sorted([i for i in plot_sym_counts.index if i not in map_sym_counts.index])

# %%
display(map_not_plot)
display(plot_not_map)
# Out:
# ['Hs', 'Qs']
# ['Hb', 'Hf', 'Ht', 'Hti', 'Htl', 'Hts', 'Jn', 'Qm', 'Qt', 'Qti', 'Qtl', 'Qu']

# %% [markdown]
# #### The prefixes "Q" and "H" respectively refer to Quaternary and Holocene. From the legend included in the data zip, the map symbols Qs and Hs are categories within which the plot symbols with the same first character fall.
# Qs (mudstone, siltstone, sandstone, conglomerate): {
# - Qti (ice sheet till),
# - Qtl (local till),
# - Qt(till, unspecified),
# - Qm (morraine)}
#
# Hs(mudstone, siltstone, sandstone, conglomerate): {
# - Htl(local till),
# - Hti(ice sheet till),
# - Ht(till, unspecified)}
# - Hts Not sure what Hts is supposed to mean. till would be a subset of s, so unless s has a separate meaning, Hts has redundant coding and should be classified as Ht

# %% [markdown]
# ### These sets leave out Hb (Mafic to ultramafic volcanic), Hf (felsic volcanic), Jn (high-grade metamorphic), Qu (Mafic to ultramafic intrusives).

# %% [markdown]
# #### Starting with Hb let's look at the corresponding map symbol, source, and name of the polygons with this plotsymbol

# %%
Hb_records = data[data["PLOTSYMBOL"] == "Hb"][["SOURCECODE", "MAPSYMBOL", "PLOTSYMBOL", "NAME", "SOURCE"]]
print(f"{Hb_records.shape[0]} polygons have PLOTSYMBOL 'Hb'")
display(Hb_records)
# Out:
# 44 polygons have PLOTSYMBOL 'Hb'
#       SOURCECODE MAPSYMBOL PLOTSYMBOL  \
# 54610         ub        Hs         Hb
# 54662         ub        Hs         Hb
# 54985         ub        Hs         Hb
# 55006         ub        Hs         Hb
# 55047         ub        Hs         Hb
# 55298         ub        Hs         Hb
# 55325         ub        Hs         Hb
# 55380         ub        Hs         Hb
# 55435         ub        Hs         Hb
# 55461         ub        Hs         Hb
# 55548         ub        Hs         Hb
# 55630         ub        Hs         Hb
# 55706         ub        Hs         Hb
# 55850         ub        Hs         Hb
# 55868         ub        Hs         Hb
# 55948         ub        Hs         Hb
# 55981         ub        Hs         Hb
# 56084         ub        Hs         Hb
# 61597         Hb        Hs         Hb
# 70673         Hb        Hs         Hb
# 71055         Hb        Hs         Hb
# 71062         Hb        Hs         Hb
# 71064         Hb        Hs         Hb
# 71066         Hb        Hs         Hb
# 71068         Hb        Hs         Hb
# 71130         Hb        Hs         Hb
# 71133         Hb        Hs         Hb
# 71221         Hb        Hs         Hb
# 71244         Hb        Hs         Hb
# 71299         Hb        Hs         Hb
# 71449         Hb        Hs         Hb
# 72714         Hb        Hs         Hb
# 73182         Hb        Hs         Hb
# 73183         Hb        Hs         Hb
# 73184         Hb        Hs         Hb
# 73295         Hb        Hs         Hb
# 73296         Hb        Hs         Hb
# 74074         Hb        Hs         Hb
# 74089         Hb        Hs         Hb
# 74090         Hb        Hs         Hb
# 74653         Hb        Hs         Hb
# 74654         Hb        Hs         Hb
# 74730         Hb        Hs         Hb
# 74731         Hb        Hs         Hb
#
#                                             NAME  \
# 54610         beach and stranded marine deposits
# 54662         beach and stranded marine deposits
# 54985         beach and stranded marine deposits
# 55006         beach and stranded marine deposits
# 55047         beach and stranded marine deposits
# 55298         beach and stranded marine deposits
# 55325         beach and stranded marine deposits
# 55380         beach and stranded marine deposits
# 55435         beach and stranded marine deposits
# 55461         beach and stranded marine deposits
# 55548         beach and stranded marine deposits
# 55630         beach and stranded marine deposits
# 55706         beach and stranded marine deposits
# 55850         beach and stranded marine deposits
# 55868         beach and stranded marine deposits
# 55948         beach and stranded marine deposits
# 55981         beach and stranded marine deposits
# 56084         beach and stranded marine deposits
# 61597  Holocene beach and raised marine deposits
# 70673  Holocene beach and raised marine deposits
# 71055  Holocene beach and raised marine deposits
# 71062  Holocene beach and raised marine deposits
# 71064  Holocene beach and raised marine deposits
# 71066  Holocene beach and raised marine deposits
# 71068  Holocene beach and raised marine deposits
# 71130  Holocene beach and raised marine deposits
# 71133  Holocene beach and raised marine deposits
# 71221  Holocene beach and raised marine deposits
# 71244  Holocene beach and raised marine deposits
# 71299  Holocene beach and raised marine deposits
# 71449  Holocene beach and raised marine deposits
# 72714  Holocene beach and raised marine deposits
# 73182  Holocene beach and raised marine deposits
# 73183  Holocene beach and raised marine deposits
# 73184  Holocene beach and raised marine deposits
# 73295  Holocene beach and raised marine deposits
# 73296  Holocene beach and raised marine deposits
# 74074  Holocene beach and raised marine deposits
# 74089  Holocene beach and raised marine deposits
# 74090  Holocene beach and raised marine deposits
# 74653  Holocene beach and raised marine deposits
# 74654  Holocene beach and raised marine deposits
# 74730  Holocene beach and raised marine deposits
# 74731  Holocene beach and raised marine deposits
#
#                                                   SOURCE
# 54610  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 54662  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 54985  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55006  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55047  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55298  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55325  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55380  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55435  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55461  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55548  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55630  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55706  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55850  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55868  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55948  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55981  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 56084  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 61597                               Ellerman & Kyle 1990
# 70673                              Pertusati et al. 2012
# 71055                             Baroni & Ombrelli 1994
# 71062                             Baroni & Ombrelli 1994
# 71064                             Baroni & Ombrelli 1994
# 71066                             Baroni & Ombrelli 1994
# 71068                             Baroni & Ombrelli 1994
# 71130                              Pertusati et al. 2012
# 71133                             Baroni & Ombrelli 1994
# 71221                              Pertusati et al. 2012
# 71244                              Pertusati et al. 2012
# 71299                                             GeoMAP
# 71449                                             GeoMAP
# 72714                               Ellerman & Kyle 1990
# 73182                                             GeoMAP
# 73183                                             GeoMAP
# 73184                                             GeoMAP
# 73295                                             GeoMAP
# 73296                                             GeoMAP
# 74074                             Baroni & Ombrelli 1994
# 74089                             Baroni & Ombrelli 1994
# 74090                                             GeoMAP
# 74653                             Baroni & Ombrelli 1994
# 74654                             Baroni & Ombrelli 1994
# 74730                                             GeoMAP
# 74731                                             GeoMAP

# %% [markdown]
# ### We have two different formation names here, one: Holocene beach and stranded marine deposits mapped by Cox, S. C. et. al. and another: Holocene beach and raised marine deposits mapped by a variety of sources.
# - These names imply that the plotsymbol's suffix 'b' corresponds to beach. This conflicts with the map symbol schema established by the legend
# - Is there a significant difference between stranded marine deposits and raised marine deposits?
# - it establishes a precedent of map symbol as a field that is more compositionally descriptive while plot symbol is more lithogenetically descriptive. Is this a desired pattern? Is this a pattern that is consistent throughout these data? How is this documented/advertised in the schema metadata?
# - Another pattern established in the second group of polys with plotsymbol 'Hb' is that it matches the source code. Is this a desired pattern? is this a consistent pattern? Where is this pattern documented?

# %% [markdown]
# ### Before examining the schema as a whole, let's focus on making sure there aren't other polygons with this formation name and a different set of symbols and codes

# %%
stranded_deposits = data[data["NAME"] == "beach and stranded marine deposits"][["SOURCECODE", "MAPSYMBOL", "PLOTSYMBOL", "NAME", "SOURCE"]]
print(f"{stranded_deposits.shape[0]} polygons have name 'beach and stranded marine deposits'")
display(stranded_deposits)
# Out:
# 18 polygons have name 'beach and stranded marine deposits'
#       SOURCECODE MAPSYMBOL PLOTSYMBOL                                NAME  \
# 54610         ub        Hs         Hb  beach and stranded marine deposits
# 54662         ub        Hs         Hb  beach and stranded marine deposits
# 54985         ub        Hs         Hb  beach and stranded marine deposits
# 55006         ub        Hs         Hb  beach and stranded marine deposits
# 55047         ub        Hs         Hb  beach and stranded marine deposits
# 55298         ub        Hs         Hb  beach and stranded marine deposits
# 55325         ub        Hs         Hb  beach and stranded marine deposits
# 55380         ub        Hs         Hb  beach and stranded marine deposits
# 55435         ub        Hs         Hb  beach and stranded marine deposits
# 55461         ub        Hs         Hb  beach and stranded marine deposits
# 55548         ub        Hs         Hb  beach and stranded marine deposits
# 55630         ub        Hs         Hb  beach and stranded marine deposits
# 55706         ub        Hs         Hb  beach and stranded marine deposits
# 55850         ub        Hs         Hb  beach and stranded marine deposits
# 55868         ub        Hs         Hb  beach and stranded marine deposits
# 55948         ub        Hs         Hb  beach and stranded marine deposits
# 55981         ub        Hs         Hb  beach and stranded marine deposits
# 56084         ub        Hs         Hb  beach and stranded marine deposits
#
#                                                   SOURCE
# 54610  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 54662  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 54985  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55006  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55047  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55298  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55325  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55380  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55435  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55461  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55548  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55630  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55706  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55850  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55868  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55948  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55981  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 56084  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...

# %% [markdown]
# #### These polygons are all consistent. Let's check 'Holocene beach and raised marine deposits'

# %%
raised_marine_deposits = data[data["NAME"] == "Holocene beach and raised marine deposits"][["SOURCECODE", "MAPSYMBOL", "PLOTSYMBOL", "NAME", "SOURCE"]]
print(f"{raised_marine_deposits.shape[0]} polygons have name 'Holocene beach and raised marine deposits'")
display(raised_marine_deposits)
# Out:
# 26 polygons have name 'Holocene beach and raised marine deposits'
#       SOURCECODE MAPSYMBOL PLOTSYMBOL  \
# 61597         Hb        Hs         Hb
# 70673         Hb        Hs         Hb
# 71055         Hb        Hs         Hb
# 71062         Hb        Hs         Hb
# 71064         Hb        Hs         Hb
# 71066         Hb        Hs         Hb
# 71068         Hb        Hs         Hb
# 71130         Hb        Hs         Hb
# 71133         Hb        Hs         Hb
# 71221         Hb        Hs         Hb
# 71244         Hb        Hs         Hb
# 71299         Hb        Hs         Hb
# 71449         Hb        Hs         Hb
# 72714         Hb        Hs         Hb
# 73182         Hb        Hs         Hb
# 73183         Hb        Hs         Hb
# 73184         Hb        Hs         Hb
# 73295         Hb        Hs         Hb
# 73296         Hb        Hs         Hb
# 74074         Hb        Hs         Hb
# 74089         Hb        Hs         Hb
# 74090         Hb        Hs         Hb
# 74653         Hb        Hs         Hb
# 74654         Hb        Hs         Hb
# 74730         Hb        Hs         Hb
# 74731         Hb        Hs         Hb
#
#                                             NAME                  SOURCE
# 61597  Holocene beach and raised marine deposits    Ellerman & Kyle 1990
# 70673  Holocene beach and raised marine deposits   Pertusati et al. 2012
# 71055  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 71062  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 71064  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 71066  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 71068  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 71130  Holocene beach and raised marine deposits   Pertusati et al. 2012
# 71133  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 71221  Holocene beach and raised marine deposits   Pertusati et al. 2012
# 71244  Holocene beach and raised marine deposits   Pertusati et al. 2012
# 71299  Holocene beach and raised marine deposits                  GeoMAP
# 71449  Holocene beach and raised marine deposits                  GeoMAP
# 72714  Holocene beach and raised marine deposits    Ellerman & Kyle 1990
# 73182  Holocene beach and raised marine deposits                  GeoMAP
# 73183  Holocene beach and raised marine deposits                  GeoMAP
# 73184  Holocene beach and raised marine deposits                  GeoMAP
# 73295  Holocene beach and raised marine deposits                  GeoMAP
# 73296  Holocene beach and raised marine deposits                  GeoMAP
# 74074  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 74089  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 74090  Holocene beach and raised marine deposits                  GeoMAP
# 74653  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 74654  Holocene beach and raised marine deposits  Baroni & Ombrelli 1994
# 74730  Holocene beach and raised marine deposits                  GeoMAP
# 74731  Holocene beach and raised marine deposits                  GeoMAP

# %% [markdown]
# ### I think we can safely say that Hb is used consistently as a PLOTSYMBOL for these two formations

# %% [markdown]
# ## Let's checkout Hf next

# %%
hf_records = data[data["PLOTSYMBOL"] == "Hf"][["SOURCECODE", "MAPSYMBOL", "PLOTSYMBOL", "NAME", "SOURCE"]]
print(f"{hf_records.shape[0]} polygons with PLOTSYMBOL Hf")
display(hf_records)
# Out:
# 6 polygons with PLOTSYMBOL Hf
#       SOURCECODE MAPSYMBOL PLOTSYMBOL          NAME  SOURCE
# 69982         Hf        Hs         Hf  Holocene fan  GeoMAP
# 73292         Hf        Hs         Hf  Holocene fan  GeoMAP
# 73294         Hf        Hs         Hf  Holocene fan  GeoMAP
# 73297         Hf        Hs         Hf  Holocene fan  GeoMAP
# 73298         Hf        Hs         Hf  Holocene fan  GeoMAP
# 73300         Hf        Hs         Hf  Holocene fan  GeoMAP

# %% [markdown]
# ### This looks pretty straightforward: Hf follows the pattern of plotsymbol being more lithogenetically descriptive and would fit under MAPSYMBOL Hs, but still conficts with the legend suffix for felsic volcanic.

# %% [markdown]
# ## Moving on to plotsymbol "Jn". Based upon the pattern of mapsymbols, "Jn" should refer to Jurassic age rocks (J) that are high-grade metamorphics (n). This plot/mapsymbol is not included in the legend.
# Let's see how many polygons have this PLOTSYMBOL and what their mapsymbol is

# %%
jn_records = data[data["PLOTSYMBOL"] == "Jn"][["SOURCECODE", "MAPSYMBOL", "PLOTSYMBOL", "NAME", "SOURCE"]]
print(f"{jn_records.shape[0]} polygons have plotsymbol 'jn'")
display(jn_records)
print(f"{len(data[data['NAME'] == 'Ruppert Coast gabbro'])} polygons have the name Ruppert Coast gabbro")
# Out:
# 13 polygons have plotsymbol 'jn'
#       SOURCECODE MAPSYMBOL PLOTSYMBOL                  NAME  \
# 41772       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41778       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41780       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41858       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41859       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41878       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41885       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41887       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41888       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41889       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41890       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41892       Jgab        Jd         Jn  Ruppert Coast gabbro
# 41905       Jgab        Jd         Jn  Ruppert Coast gabbro
#
#                      SOURCE
# 41772  Metcalfe et al. 1978
# 41778  Metcalfe et al. 1978
# 41780  Metcalfe et al. 1978
# 41858  Metcalfe et al. 1978
# 41859  Metcalfe et al. 1978
# 41878  Metcalfe et al. 1978
# 41885  Metcalfe et al. 1978
# 41887  Metcalfe et al. 1978
# 41888  Metcalfe et al. 1978
# 41889  Metcalfe et al. 1978
# 41890  Metcalfe et al. 1978
# 41892  Metcalfe et al. 1978
# 41905  Metcalfe et al. 1978
# 13 polygons have the name Ruppert Coast gabbro

# %% [markdown]
# ### The source should be checked for these polygons. All of the polgyons labeled as "Ruppert Coast gabbro" are mapped by Metcalfe et al. 1978. If the source indicates the formation is mafic (d) (as gabbro would suggest), the plot symbol should be changed. If the formation is metamorphic, the map symbol should be changed.
#
# #### There is also the possibility that the combination of map symbol and plot symbol is suggesting that the formation is a metamorphosed gabbro.

# %% [markdown]
# ## Finally, Qu

# %%
qu_records = data[data["PLOTSYMBOL"] == "Qu"][["SOURCECODE", "MAPSYMBOL", "PLOTSYMBOL", "NAME", "SOURCE"]]
print(f"{qu_records.shape[0]} polygons have plotsymbol 'jn'")
display(qu_records)
# Out:
# 123 polygons have plotsymbol 'jn'
#       SOURCECODE MAPSYMBOL PLOTSYMBOL             NAME  \
# 55299         ue        Qs         Qu  deltaic deposit
# 55351         uf        Qs         Qu      fan deposit
# 55355         ue        Qs         Qu  deltaic deposit
# 55433         uf        Qs         Qu      fan deposit
# 55453         uf        Qs         Qu      fan deposit
# ...          ...       ...        ...              ...
# 58821         uf        Qs         Qu      fan deposit
# 58861         uf        Qs         Qu      fan deposit
# 60703         ua        Qs         Qu         alluvium
# 60727         ua        Qs         Qu         alluvium
# 60817         uf        Qs         Qu      fan deposit
#
#                                                   SOURCE
# 55299  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55351  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55355  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55433  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 55453  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# ...                                                  ...
# 58821  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 58861  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 60703  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 60727  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
# 60817  Cox, S.C.; Turnbull, I.M.; Isaac, M.J.; Townse...
#
# [123 rows x 5 columns]

# %% [markdown]
# ### This is a relatively large number of polygons with a few different names represented. Let's look at their frequency

# %%
display(qu_records["NAME"].value_counts())
# Out:
# fan deposit                       80
# deltaic deposit                   22
# alluvium                          11
# dune sand and aeolian deposits     7
# cover - undifferentiated           2
# cover - lacustrine deposit?        1
# Name: NAME, dtype: int64

# %% [markdown]
# ### I'm guessing that Qu is meant to indicate "quaternary unknown or undifferentiated"
# - u should probably not be used to indicate mafic to ultramafic intrusives.
# - these fan deposit polys should probably have plotsymbol "Qf"
# - perhaps there's a need for a separate legend or at least glossary for plotsymbol values.

# %% [markdown]
# ## Are there other plotsymbols that do not conform to the legend? How would we find these?

# %% [markdown]
# ## Going off on another direction, based upon the legend, mapsymbol values should have lengths between 2 and 3 characters. Do the data conform to this expectation?

# %%
map_sym_len_counts = pd.DataFrame([len(i) for i in map_sym_counts.index]).value_counts()
display(map_sym_len_counts)
# Out:
# 2    84
# 3    78
# 4     9
# 5     1
# 1     1
# dtype: int64

# %% [markdown]
# ### All but 11 conform. What values are these?

# %%
map_sym_len_anomalies = [i for i in map_sym_counts.index if len(i) not in [2, 3]]
print(map_sym_len_anomalies)
# Out:
# ['?', 'water', 'KCzv', 'PzJs', 'ARzn', 'PzTn', 'ARzx', 'RzEn', 'PzTs', 'RzEg', 'ARzg']

# %% [markdown]
# ### after looking at the legend again, 4 character symbols work for units that span from an era into a period.
# #### water and ? are self explanatory.
# ## There seem to be no MAPSYMBOL length anomalies
